# %% [markdown]
# # AI ENGINEER HACKATHON CODE
#
# So, there will be 2 different sections in this notebook, the first section will contain, hindi-to-english translation, summarization and sentiment analysis of the subsequent conversation (which was translated to English), and the second section, which contains direct sentiment analysis in Hindi using different models through the HuggingFace API, models that understand Hindi as well.

# %% [markdown]
# ## SECTION 1: HINDI-TO-ENGLISH TRANSLATION, SUMMARIZATION AND SENTIMENT ANALYSIS

# %%
import transformers

# %%
conversation_hindi = """Speaker 1: नमस्ते, मैं राजेश बोल रहा हूँ, CFI फाइनेंस कंपनी से। क्या मैं श्री सुरेश कुमार से बात कर सकता हूँ?
Speaker 2: हाँ, मैं ही सुरेश बोल रहा हूँ। क्या बात है?
Speaker 1: सुरेशजी, मैं आपके लोन के बारे में बात करने के लिए फोन कर रहा हूँ। आपका EMI पिछले तीन महीने से बकाया है।
Speaker 2: अरे हाँ, मुझे पता है। लेकिन आप लोग हर रोज फोन करके परेशान कर रहे हैं। मैंने कहा था ना कि जैसे ही पैसे होंगे, मैं भर दूंगा।
Speaker 1: देखिए सुरेशजी, हम समझते हैं आपकी परेशानी। लेकिन आप भी समझिए, यह हमारा काम है। आपको पता है कि आपके ऊपर कितना बकाया है?
Speaker 2: हाँ-हाँ, मुझे अंदाजा है। लगभग 50,000 रुपये होंगे।
Speaker 1: नहीं सुरेशजी, आप गलत हैं। आप पर कुल 75,000 रुपये बकाया है, जिसमें लेट फीस और ब्याज भी शामिल है।
Speaker 2: क्या? इतने ज्यादा? यह कैसे हो सकता है? आप लोग लूट रहे हैं क्या?
Speaker 1: देखिए सुरेशजी, गुस्सा करने से कुछ नहीं होगा। आपको समय पर पैसे जमा करने चाहिए थे। अब बताइए, कब तक आप यह राशि जमा कर सकते हैं?
Speaker 2: अरे भाई, मेरी बात तो सुनो! मेरी माँ की तबीयत खराब है, अस्पताल में भर्ती हैं। सारे पैसे उनके इलाज में खर्च हो गए।
Speaker 1:  सुरेशजी, मुझे आपकी परिस्थिति से कोई मतलब नहीं है। हमें बस अपना पैसा चाहिए। आप समझ रहे हैं या नहीं?
Speaker 2: क्या बकवास कर रहे हो? तुम्हें शर्म नहीं आती? मेरी माँ मरने की कगार पर हैं और तुम पैसों की बात कर रहे हो?
Speaker 1:  देखो सुरेश, मुझे तुम्हारी कहानियों से कोई फर्क नहीं पड़ता। तुमने लोन लिया है तो चुकाना पड़ेगा। समझे? वरना हम कानूनी कार्रवाई करेंगे।
Speaker 2: तुम धमकी दे रहे हो? तुम्हें पता है मैं कौन हूँ? मैं तुम्हारी नौकरी गंवा सकता हूँ।
Speaker 1:  अरे वाह! अब तुम भी धमकी दे रहे हो? चलो, देखते हैं कौन क्या कर सकता है। तुम अपनी माँ का इलाज करवाओ, मैं तुम्हारा इलाज करूँगा।
Speaker 2: बदतमीज! तुम्हारी हिम्मत कैसे हुई ऐसे बात करने की? मैं तुम्हारे बॉस से शिकायत करूँगा।
Speaker 1: करो जो करना है। लेकिन याद रखना, अगर कल तक पैसे नहीं आए तो मैं खुद तुम्हारे घर आऊंगा। और तब देखेंगे कौन किसका इलाज करता है।
Speaker 2: तुम मेरे घर आओगे? ठीक है, आ जाओ। देखता हूँ कैसे आते हो। मैं पुलिस को बुला लूंगा।
Speaker 1: अरे वाह! पुलिस? बहुत अच्छा। हम भी देखेंगे कि पुलिस किसका साथ देती है - एक कर्जदार का या एक कानूनी कंपनी का।
Speaker 2: तुम... तुम बहुत बुरे इंसान हो। मेरी मजबूरी का फायदा उठा रहे हो।
Speaker 1:  हाँ-हाँ, मैं बहुत बुरा हूँ। लेकिन तुमसे तो अच्छा ही हूँ। कम से कम मैं अपने वादे तो पूरे करता हूँ।
Speaker 2: क्या मतलब? मैंने कभी वादा तोड़ा है क्या?
Speaker 1: अरे सुरेश भाई, तुमने हर महीने EMI भरने का वादा किया था। वो क्या हुआ? भूल गए?
Speaker 2:  देखो, मैं समझता हूँ। लेकिन अभी मेरे पास सच में पैसे नहीं हैं। क्या कोई और तरीका नहीं है?
Speaker 1: तरीका तो है। लेकिन उसके लिए तुम्हें कुछ करना होगा।
Speaker 2: क्या करना होगा? बताओ, मैं तैयार हूँ।
Speaker 1: पहले तो अपनी माँ का इलाज बंद करो। उन पैसों से हमारा कर्ज चुका दो।
Speaker 2:  क्या बकवास कर रहे हो? तुम पागल हो गए हो क्या?
Speaker 1: अरे नहीं-नहीं, मैं तो मजाक कर रहा था। तुम तो बहुत जल्दी गुस्सा हो जाते हो।
Speaker 2:  तुम्हें यह सब मजाक लगता है? मेरी जिंदगी बर्बाद हो रही है और तुम मजाक कर रहे हो?
Speaker 1: अच्छा सुनो, मैं तुम्हें एक और मौका देता हूँ। कल तक 25,000 रुपये जमा कर दो। बाकी के लिए हम एक नया प्लान बना लेंगे।
Speaker 2: 25,000? इतने पैसे कहाँ से लाऊँ मैं?
Speaker 1: वो तुम्हारी समस्या है। चाहे दोस्तों से उधार लो, या फिर कुछ बेच दो। लेकिन कल तक पैसे चाहिए।
Speaker 2: तुम समझ क्यों नहीं रहे हो? मेरे पास सच में पैसे नहीं हैं।
Speaker 1: देखो सुरेश, मुझे लगता है तुम समझ नहीं रहे हो। अगर तुम कल तक पैसे नहीं देते, तो मैं तुम्हारे ऑफिस आऊंगा और सबके सामने तुम्हारी पोल खोल दूंगा।
Speaker 2:  नहीं-नहीं, ऐसा मत करना। मेरी इज्जत का सवाल है।
Speaker 1: तो फिर ठीक है। कल तक पैसे जमा कर दो। वरना तुम जानते हो क्या होगा।
Speaker 2: ठीक है, मैं कोशिश करूँगा। लेकिन प्लीज, मेरे ऑफिस मत आना।
Speaker 1: बहुत अच्छा। अब तुम समझदारी की बात कर रहे हो। याद रखना, कल शाम 5 बजे तक पैसे नहीं आए तो मैं सीधा तुम्हारे ऑफिस पहुँच जाऊंगा।
Speaker 2: हाँ-हाँ, मैं समझ गया। मैं पूरी कोशिश करूँगा।
Speaker 1: ठीक है। और हाँ, अगली बार जब लोन लो तो याद रखना - समय पर पैसे नहीं चुकाओगे तो ऐसे ही परेशान होना पड़ेगा।
Speaker 2:  हाँ, मैं समझ गया। अब मैं रखता हूँ।
Speaker 1: ठीक है। और याद रखना, कल शाम 5 बजे। एक मिनट की भी देरी हुई तो...
Speaker 2: हाँ-हाँ, मैंने कहा ना मैं कोशिश करूँगा।
Speaker 1: कोशिश नहीं, करना होगा। समझे? अच्छा, अब रखता हूँ। कल मिलते हैं - या तो बैंक में, या फिर तुम्हारे ऑफिस में।
Speaker 2:  हाँ, ठीक है। नमस्ते।
"""

# %% [markdown]
# ### TRANSLATION

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

#using the mbart translation model from facebook, as at some point the conversation would have to be translated to english to summarize it.

model_name = "facebook/mbart-large-50-many-to-many-mmt"
model = MBartForConditionalGeneration.from_pretrained(model_name)
tokenizer = MBart50TokenizerFast.from_pretrained(model_name)

#to avoid exceeding input token length, I have split the conversation into segments, each segment separated by a newline and after ignoring empty strings, the code translates each
#line into Hindi and appends it to the full_translation variable

conv_segments = conversation_hindi.split("\n")
translated_conv_segments = []

for segment in conv_segments:
    if segment.strip(): 
        tokenizer.src_lang = "hi_IN"
        encoded_hi = tokenizer(segment, return_tensors="pt") #forms tokens in Hindi language
        generated_tokens = model.generate(**encoded_hi, forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"])
        translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0] #decodes the generated tokens for each segment
        translated_conv_segments.append(translation)

full_translation = "\n".join(translated_conv_segments)

print("Full Translation:\n", full_translation)
# Out:
# Full Translation:
#  Speaker 1: Hello, I'm speaking to Rajesh, CFI Finance Company. Can I speak to Shri Suresh Kumar?
# Speaker 2: Yes, I'm Suresh. What' s the matter?
# Speaker 1: Sureshji, I'm calling to talk about your loan. Your EMI has been outstanding for the last three months.
# Speaker 2: Oh yeah, I know. But you guys are bothering by calling every day. I said no, as soon as there's money, I' ll pay.
# Speaker 1: Look Sureshji, we understand your trouble. But you also understand, this is our job. Do you know how much you have left over?
# Speaker 2: Yes - yes, I guess. About Rs. 50, 000.
# Speaker 1: No Sureshji, you are wrong. You owe a total of Rs 75, 000 including late fees and interest.
# Speaker 2: What? So much? How could it be? Are you guys looting?
# Speaker 1: Look Sureshji, there's nothing to be angry about. You should have deposited money on time. Now tell me, how long can you deposit this amount?
# Speaker 2: Oh brother, listen to me! My mother's condition is bad, admitted to the hospital. All the money is spent on her treatment.
# Speaker 1: Sureshji, I don 't care about your situation. We just need your money. Do you understand?
# What are you talking about? Don 't you feel ashamed? My mother is about to die and you' re talking about money?
# Speaker 1: Look Suresh, I don 't care about your stories. You have to pay for the loan. You understand? Otherwise we' ll take legal action.
# Speaker 2: Are you threatening? You know who I am? I can lose your job.
# Speaker 1: Oh wow! Now you're threatening too? Let' s see who can do it. You treat your mother, I 'll treat you.
# How dare you say that? I 'll complain to your boss.
# Speaker 1: Do what you have to do. But remember, if you don 't get the money tomorrow, I' ll come to your house myself. And then we 'll see who treats who.
# Speaker 2: Will you come to my house? All right, come. I 'll see how you come. I' ll call the police.
# Speaker 1: Oh, wow! The police? Very good. We 'll also see who the police deal with - a debtor or a legal company.
# Speaker 2: You... you're a very bad man. You' re taking advantage of my compulsion.
# Speaker 1: Yes - yes, I'm very bad. But I' m better than you. At least I 'll keep my promise.
# Speaker 2: What do you mean? Have I ever made a promise?
# Speaker 1: Oh Suresh brother, you promised to pay EMI every month. What happened? Forgot?
# Speaker 2: Look, I understand. But right now I don 't really have the money. Isn' t there any other way?
# Speaker 1: There's a way. But for that you have to do something.
# Speaker 2: What do you have to do? Tell me, I'm ready.
# Speaker 1: Stop treating your mother first. Pay off our debts with those amounts.
# Speaker 2: What are you talking about? Are you crazy?
# Speaker 1: Oh no - no, I was kidding. You get angry very quickly.
# Speaker 2: Are you kidding me? My life is being wasted and you are kidding me?
# Speaker 1: Well listen, I 'll give you another chance. Deposit Rs. 25, 000 till tomorrow. We' ll make a new plan for the rest.
# Speaker 2: 25,000? Where do I get that much money?
# Speaker 1: That's your problem. Either borrow from friends, or sell something. But you need money till tomorrow.
# Speaker 2: Why don 't you understand? I don' t really have the money.
# Speaker 1: Look Suresh, I don 't think you understand. If you don' t pay till tomorrow, I 'll come to your office and open your mailbox in front of everyone.
# Speaker 2: No - no, don 't do that. It' s my honor.
# Speaker 1: Then all right. Save the money till tomorrow. Otherwise you know what 'll happen.
# Speaker 2: Okay, I 'll try. But please don' t come to my office.
# Speaker 1: Very good. Now you're talking intelligence. Remember, if you don' t get any money by 5 p. m. tomorrow evening, I 'll go straight to your office.
# Speaker 2: Yes - yes, I understand. I 'll try my best.
# Speaker 1: All right. And yes, the next time you take the rope, remember - if you don 't pay in time, you' ll have to be bothered.
# Speaker 2: Yes, I got it. Now I put it.
# Speaker 1: Okay. And remember, 5 p.m. yesterday evening. One minute too late, so...
# Speaker 2: Yes - yes, I said no, I 'll try.
# Speaker 1: Don 't try, have to. You understand? Well, I' ll put it now. See you tomorrow - either in the bank, or in your office.
# Speaker 2: Yes, all right. Goodbye.

# %% [markdown]
# ### CONVERSATION SUMMARIZATION

# %% [markdown]
# ### SENTIMENT ANALYSIS OF THE CONVERSATION

# %%
sentiment_analyzer_instance = pipeline("sentiment-analysis")
#we stick to the default sentiment analysis model

conversation_lines = full_translation.split("\n")
#extracting line by line sentiment of the text
conversation_sentiments = []

for line in conversation_lines:
    if line.strip():
        sentiment = sentiment_analyzer_instance(line)
        conversation_sentiments.append((line.strip(), sentiment))

for line, sentiment in conversation_sentiments:
    print(f"Text: {line}")
    #printing sentiments line-by-line
    print(f"Sentiment: {sentiment}\n")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Text: Speaker 1: Hello, I'm speaking to Rajesh, CFI Finance Company. Can I speak to Shri Suresh Kumar?
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9870790243148804}]
#
# Text: Speaker 2: Yes, I'm Suresh. What' s the matter?
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9634444713592529}]
#
# Text: Speaker 1: Sureshji, I'm calling to talk about your loan. Your EMI has been outstanding for the last three months.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9930793642997742}]
#
# Text: Speaker 2: Oh yeah, I know. But you guys are bothering by calling every day. I said no, as soon as there's money, I' ll pay.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9951926469802856}]
#
# Text: Speaker 1: Look Sureshji, we understand your trouble. But you also understand, this is our job. Do you know how much you have left over?
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9611043334007263}]
#
# Text: Speaker 2: Yes - yes, I guess. About Rs. 50, 000.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.7793845534324646}]
#
# Text: Speaker 1: No Sureshji, you are wrong. You owe a total of Rs 75, 000 including late fees and interest.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9874401092529297}]
#
# Text: Speaker 2: What? So much? How could it be? Are you guys looting?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9988982677459717}]
#
# Text: Speaker 1: Look Sureshji, there's nothing to be angry about. You should have deposited money on time. Now tell me, how long can you deposit this amount?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9885300993919373}]
#
# Text: Speaker 2: Oh brother, listen to me! My mother's condition is bad, admitted to the hospital. All the money is spent on her treatment.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9987937211990356}]
#
# Text: Speaker 1: Sureshji, I don 't care about your situation. We just need your money. Do you understand?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9991839528083801}]
#
# Text: What are you talking about? Don 't you feel ashamed? My mother is about to die and you' re talking about money?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.8208991885185242}]
#
# Text: Speaker 1: Look Suresh, I don 't care about your stories. You have to pay for the loan. You understand? Otherwise we' ll take legal action.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9993374943733215}]
#
# Text: Speaker 2: Are you threatening? You know who I am? I can lose your job.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9997351765632629}]
#
# Text: Speaker 1: Oh wow! Now you're threatening too? Let' s see who can do it. You treat your mother, I 'll treat you.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9993507266044617}]
#
# Text: How dare you say that? I 'll complain to your boss.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9993116855621338}]
#
# Text: Speaker 1: Do what you have to do. But remember, if you don 't get the money tomorrow, I' ll come to your house myself. And then we 'll see who treats who.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9419719576835632}]
#
# Text: Speaker 2: Will you come to my house? All right, come. I 'll see how you come. I' ll call the police.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.994573175907135}]
#
# Text: Speaker 1: Oh, wow! The police? Very good. We 'll also see who the police deal with - a debtor or a legal company.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9997606873512268}]
#
# Text: Speaker 2: You... you're a very bad man. You' re taking advantage of my compulsion.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9922332763671875}]
#
# Text: Speaker 1: Yes - yes, I'm very bad. But I' m better than you. At least I 'll keep my promise.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9995131492614746}]
#
# Text: Speaker 2: What do you mean? Have I ever made a promise?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9705760478973389}]
#
# Text: Speaker 1: Oh Suresh brother, you promised to pay EMI every month. What happened? Forgot?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.998336136341095}]
#
# Text: Speaker 2: Look, I understand. But right now I don 't really have the money. Isn' t there any other way?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9995071887969971}]
#
# Text: Speaker 1: There's a way. But for that you have to do something.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.5240094065666199}]
#
# Text: Speaker 2: What do you have to do? Tell me, I'm ready.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9944941401481628}]
#
# Text: Speaker 1: Stop treating your mother first. Pay off our debts with those amounts.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9961090683937073}]
#
# Text: Speaker 2: What are you talking about? Are you crazy?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9791961312294006}]
#
# Text: Speaker 1: Oh no - no, I was kidding. You get angry very quickly.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9957656860351562}]
#
# Text: Speaker 2: Are you kidding me? My life is being wasted and you are kidding me?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.997586727142334}]
#
# Text: Speaker 1: Well listen, I 'll give you another chance. Deposit Rs. 25, 000 till tomorrow. We' ll make a new plan for the rest.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9423624277114868}]
#
# Text: Speaker 2: 25,000? Where do I get that much money?
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9978849291801453}]
#
# Text: Speaker 1: That's your problem. Either borrow from friends, or sell something. But you need money till tomorrow.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.995428204536438}]
#
# Text: Speaker 2: Why don 't you understand? I don' t really have the money.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9996786117553711}]
#
# Text: Speaker 1: Look Suresh, I don 't think you understand. If you don' t pay till tomorrow, I 'll come to your office and open your mailbox in front of everyone.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9879521727561951}]
#
# Text: Speaker 2: No - no, don 't do that. It' s my honor.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9992465972900391}]
#
# Text: Speaker 1: Then all right. Save the money till tomorrow. Otherwise you know what 'll happen.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9957180619239807}]
#
# Text: Speaker 2: Okay, I 'll try. But please don' t come to my office.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9966588020324707}]
#
# Text: Speaker 1: Very good. Now you're talking intelligence. Remember, if you don' t get any money by 5 p. m. tomorrow evening, I 'll go straight to your office.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9986536502838135}]
#
# Text: Speaker 2: Yes - yes, I understand. I 'll try my best.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9918432831764221}]
#
# Text: Speaker 1: All right. And yes, the next time you take the rope, remember - if you don 't pay in time, you' ll have to be bothered.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9867053627967834}]
#
# Text: Speaker 2: Yes, I got it. Now I put it.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.9853192567825317}]
#
# Text: Speaker 1: Okay. And remember, 5 p.m. yesterday evening. One minute too late, so...
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9951021671295166}]
#
# Text: Speaker 2: Yes - yes, I said no, I 'll try.
# Sentiment: [{'label': 'NEGATIVE', 'score': 0.9596437811851501}]
#
# Text: Speaker 1: Don 't try, have to. You understand? Well, I' ll put it now. See you tomorrow - either in the bank, or in your office.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.8157106637954712}]
#
# Text: Speaker 2: Yes, all right. Goodbye.
# Sentiment: [{'label': 'POSITIVE', 'score': 0.7776209115982056}]

# %% [markdown]
# ## SECTION TWO: SENTIMENT ANALYSIS IN THE BASE HINDI LANGUAGE AS OUTPUTTED BY 2 DIFFERENT MULTILINGUAL MODELS

# %% [markdown]
# ### SENTIMENT ANALYSIS USING THE XLM-Roberta model

# %%
sentiment_analyzer_1 = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

conversation_lines = conversation_hindi.split("\n")
sentiments = []

#the below mapping is done to ensure interpretable results.
star_to_sentiment = {
    "1 star": "very negative",
    "2 stars": "negative",
    "3 stars": "neutral",
    "4 stars": "positive",
    "5 stars": "very positive"
}

# Analyze sentiment for each line
for line in conversation_lines:
    #ignoring any potential empty lines in the conv
    if line.strip():
        sentiment = sentiment_analyzer_1(line)
        sentiment_label = star_to_sentiment[sentiment[0]['label']]
        sentiments.append((line.strip(), sentiment_label, sentiment[0]['score']))

for line, sentiment, score in sentiments:
    print(f"Text: {line}")
    print(f"Sentiment: {sentiment} (Score: {score})\n")
    #prints sentiments detected line by line
# Out:
# Text: Speaker 1: नमस्ते, मैं राजेश बोल रहा हूँ, CFI फाइनेंस कंपनी से। क्या मैं श्री सुरेश कुमार से बात कर सकता हूँ?
# Sentiment: very negative (Score: 0.25782981514930725)
#
# Text: Speaker 2: हाँ, मैं ही सुरेश बोल रहा हूँ। क्या बात है?
# Sentiment: very negative (Score: 0.27723991870880127)
#
# Text: Speaker 1: सुरेशजी, मैं आपके लोन के बारे में बात करने के लिए फोन कर रहा हूँ। आपका EMI पिछले तीन महीने से बकाया है।
# Sentiment: very negative (Score: 0.2720958888530731)
#
# Text: Speaker 2: अरे हाँ, मुझे पता है। लेकिन आप लोग हर रोज फोन करके परेशान कर रहे हैं। मैंने कहा था ना कि जैसे ही पैसे होंगे, मैं भर दूंगा।
# Sentiment: negative (Score: 0.33125725388526917)
#
# Text: Speaker 1: देखिए सुरेशजी, हम समझते हैं आपकी परेशानी। लेकिन आप भी समझिए, यह हमारा काम है। आपको पता है कि आपके ऊपर कितना बकाया है?
# Sentiment: neutral (Score: 0.369980126619339)
#
# Text: Speaker 2: हाँ-हाँ, मुझे अंदाजा है। लगभग 50,000 रुपये होंगे।
# Sentiment: very negative (Score: 0.5467532873153687)
#
# Text: Speaker 1: नहीं सुरेशजी, आप गलत हैं। आप पर कुल 75,000 रुपये बकाया है, जिसमें लेट फीस और ब्याज भी शामिल है।
# Sentiment: very negative (Score: 0.7254290580749512)
#
# Text: Speaker 2: क्या? इतने ज्यादा? यह कैसे हो सकता है? आप लोग लूट रहे हैं क्या?
# Sentiment: very negative (Score: 0.4479335844516754)
#
# Text: Speaker 1: देखिए सुरेशजी, गुस्सा करने से कुछ नहीं होगा। आपको समय पर पैसे जमा करने चाहिए थे। अब बताइए, कब तक आप यह राशि जमा कर सकते हैं?
# Sentiment: negative (Score: 0.3452354967594147)
#
# Text: Speaker 2: अरे भाई, मेरी बात तो सुनो! मेरी माँ की तबीयत खराब है, अस्पताल में भर्ती हैं। सारे पैसे उनके इलाज में खर्च हो गए।
# Sentiment: very positive (Score: 0.47318220138549805)
#
# Text: Speaker 1:  सुरेशजी, मुझे आपकी परिस्थिति से कोई मतलब नहीं है। हमें बस अपना पैसा चाहिए। आप समझ रहे हैं या नहीं?
# Sentiment: neutral (Score: 0.2534899115562439)
#
# Text: Speaker 2: क्या बकवास कर रहे हो? तुम्हें शर्म नहीं आती? मेरी माँ मरने की कगार पर हैं और तुम पैसों की बात कर रहे हो?
# Sentiment: very negative (Score: 0.39118751883506775)
#
# Text: Speaker 1:  देखो सुरेश, मुझे तुम्हारी कहानियों से कोई फर्क नहीं पड़ता। तुमने लोन लिया है तो चुकाना पड़ेगा। समझे? वरना हम कानूनी कार्रवाई करेंगे।
# Sentiment: very negative (Score: 0.6169214844703674)
#
# Text: Speaker 2: तुम धमकी दे रहे हो? तुम्हें पता है मैं कौन हूँ? मैं तुम्हारी नौकरी गंवा सकता हूँ।
# Sentiment: negative (Score: 0.31513673067092896)
#
# Text: Speaker 1:  अरे वाह! अब तुम भी धमकी दे रहे हो? चलो, देखते हैं कौन क्या कर सकता है। तुम अपनी माँ का इलाज करवाओ, मैं तुम्हारा इलाज करूँगा।
# Sentiment: very positive (Score: 0.2738388776779175)
#
# Text: Speaker 2: बदतमीज! तुम्हारी हिम्मत कैसे हुई ऐसे बात करने की? मैं तुम्हारे बॉस से शिकायत करूँगा।
# Sentiment: very negative (Score: 0.6454119086265564)
#
# Text: Speaker 1: करो जो करना है। लेकिन याद रखना, अगर कल तक पैसे नहीं आए तो मैं खुद तुम्हारे घर आऊंगा। और तब देखेंगे कौन किसका इलाज करता है।
# Sentiment: neutral (Score: 0.35566821694374084)
#
# Text: Speaker 2: तुम मेरे घर आओगे? ठीक है, आ जाओ। देखता हूँ कैसे आते हो। मैं पुलिस को बुला लूंगा।
# Sentiment: very negative (Score: 0.30758899450302124)
#
# Text: Speaker 1: अरे वाह! पुलिस? बहुत अच्छा। हम भी देखेंगे कि पुलिस किसका साथ देती है - एक कर्जदार का या एक कानूनी कंपनी का।
# Sentiment: positive (Score: 0.2608965039253235)
#
# Text: Speaker 2: तुम... तुम बहुत बुरे इंसान हो। मेरी मजबूरी का फायदा उठा रहे हो।
# Sentiment: negative (Score: 0.4083264172077179)
#
# Text: Speaker 1:  हाँ-हाँ, मैं बहुत बुरा हूँ। लेकिन तुमसे तो अच्छा ही हूँ। कम से कम मैं अपने वादे तो पूरे करता हूँ।
# Sentiment: neutral (Score: 0.4901754558086395)
#
# Text: Speaker 2: क्या मतलब? मैंने कभी वादा तोड़ा है क्या?
# Sentiment: very negative (Score: 0.34316474199295044)
#
# Text: Speaker 1: अरे सुरेश भाई, तुमने हर महीने EMI भरने का वादा किया था। वो क्या हुआ? भूल गए?
# Sentiment: very negative (Score: 0.386381596326828)
#
# Text: Speaker 2:  देखो, मैं समझता हूँ। लेकिन अभी मेरे पास सच में पैसे नहीं हैं। क्या कोई और तरीका नहीं है?
# Sentiment: neutral (Score: 0.3666069805622101)
#
# Text: Speaker 1: तरीका तो है। लेकिन उसके लिए तुम्हें कुछ करना होगा।
# Sentiment: neutral (Score: 0.4969775378704071)
#
# Text: Speaker 2: क्या करना होगा? बताओ, मैं तैयार हूँ।
# Sentiment: neutral (Score: 0.3156335949897766)
#
# Text: Speaker 1: पहले तो अपनी माँ का इलाज बंद करो। उन पैसों से हमारा कर्ज चुका दो।
# Sentiment: negative (Score: 0.37981727719306946)
#
# Text: Speaker 2:  क्या बकवास कर रहे हो? तुम पागल हो गए हो क्या?
# Sentiment: very negative (Score: 0.36893022060394287)
#
# Text: Speaker 1: अरे नहीं-नहीं, मैं तो मजाक कर रहा था। तुम तो बहुत जल्दी गुस्सा हो जाते हो।
# Sentiment: negative (Score: 0.44849950075149536)
#
# Text: Speaker 2:  तुम्हें यह सब मजाक लगता है? मेरी जिंदगी बर्बाद हो रही है और तुम मजाक कर रहे हो?
# Sentiment: negative (Score: 0.4204336106777191)
#
# Text: Speaker 1: अच्छा सुनो, मैं तुम्हें एक और मौका देता हूँ। कल तक 25,000 रुपये जमा कर दो। बाकी के लिए हम एक नया प्लान बना लेंगे।
# Sentiment: negative (Score: 0.22531485557556152)
#
# Text: Speaker 2: 25,000? इतने पैसे कहाँ से लाऊँ मैं?
# Sentiment: very negative (Score: 0.5030364990234375)
#
# Text: Speaker 1: वो तुम्हारी समस्या है। चाहे दोस्तों से उधार लो, या फिर कुछ बेच दो। लेकिन कल तक पैसे चाहिए।
# Sentiment: neutral (Score: 0.4203539490699768)
#
# Text: Speaker 2: तुम समझ क्यों नहीं रहे हो? मेरे पास सच में पैसे नहीं हैं।
# Sentiment: very negative (Score: 0.41043755412101746)
#
# Text: Speaker 1: देखो सुरेश, मुझे लगता है तुम समझ नहीं रहे हो। अगर तुम कल तक पैसे नहीं देते, तो मैं तुम्हारे ऑफिस आऊंगा और सबके सामने तुम्हारी पोल खोल दूंगा।
# Sentiment: very negative (Score: 0.22091630101203918)
#
# Text: Speaker 2:  नहीं-नहीं, ऐसा मत करना। मेरी इज्जत का सवाल है।
# Sentiment: very negative (Score: 0.294423371553421)
#
# Text: Speaker 1: तो फिर ठीक है। कल तक पैसे जमा कर दो। वरना तुम जानते हो क्या होगा।
# Sentiment: negative (Score: 0.39751559495925903)
#
# Text: Speaker 2: ठीक है, मैं कोशिश करूँगा। लेकिन प्लीज, मेरे ऑफिस मत आना।
# Sentiment: neutral (Score: 0.3881746530532837)
#
# Text: Speaker 1: बहुत अच्छा। अब तुम समझदारी की बात कर रहे हो। याद रखना, कल शाम 5 बजे तक पैसे नहीं आए तो मैं सीधा तुम्हारे ऑफिस पहुँच जाऊंगा।
# Sentiment: very positive (Score: 0.3574056029319763)
#
# Text: Speaker 2: हाँ-हाँ, मैं समझ गया। मैं पूरी कोशिश करूँगा।
# Sentiment: very positive (Score: 0.5811231732368469)
#
# Text: Speaker 1: ठीक है। और हाँ, अगली बार जब लोन लो तो याद रखना - समय पर पैसे नहीं चुकाओगे तो ऐसे ही परेशान होना पड़ेगा।
# Sentiment: negative (Score: 0.2901894152164459)
#
# Text: Speaker 2:  हाँ, मैं समझ गया। अब मैं रखता हूँ।
# Sentiment: very positive (Score: 0.5826948285102844)
#
# Text: Speaker 1: ठीक है। और याद रखना, कल शाम 5 बजे। एक मिनट की भी देरी हुई तो...
# Sentiment: neutral (Score: 0.2685765326023102)
#
# Text: Speaker 2: हाँ-हाँ, मैंने कहा ना मैं कोशिश करूँगा।
# Sentiment: very negative (Score: 0.26485762000083923)
#
# Text: Speaker 1: कोशिश नहीं, करना होगा। समझे? अच्छा, अब रखता हूँ। कल मिलते हैं - या तो बैंक में, या फिर तुम्हारे ऑफिस में।
# Sentiment: very positive (Score: 0.24859480559825897)
#
# Text: Speaker 2:  हाँ, ठीक है। नमस्ते।
# Sentiment: negative (Score: 0.31614649295806885)

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

model_name = "j-hartmann/emotion-english-distilroberta-base"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

sentiment_analyzer_2 = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

conversation_lines = conversation_hindi.split("\n")
sentiments = []

for line in conversation_lines:
    if line.strip():  # Skip empty lines as it gives garbage output
        sentiment = sentiment_analyzer_2(line)
        sentiments.append((line.strip(), sentiment))

for line, sentiment in sentiments:
    print(f"Text: {line}")
    print(f"Sentiment: {sentiment}\n")
# Out:
# Text: Speaker 1: नमस्ते, मैं राजेश बोल रहा हूँ, CFI फाइनेंस कंपनी से। क्या मैं श्री सुरेश कुमार से बात कर सकता हूँ?
# Sentiment: [{'label': 'neutral', 'score': 0.7539621591567993}]
#
# Text: Speaker 2: हाँ, मैं ही सुरेश बोल रहा हूँ। क्या बात है?
# Sentiment: [{'label': 'neutral', 'score': 0.7175516486167908}]
#
# Text: Speaker 1: सुरेशजी, मैं आपके लोन के बारे में बात करने के लिए फोन कर रहा हूँ। आपका EMI पिछले तीन महीने से बकाया है।
# Sentiment: [{'label': 'neutral', 'score': 0.7517766952514648}]
#
# Text: Speaker 2: अरे हाँ, मुझे पता है। लेकिन आप लोग हर रोज फोन करके परेशान कर रहे हैं। मैंने कहा था ना कि जैसे ही पैसे होंगे, मैं भर दूंगा।
# Sentiment: [{'label': 'neutral', 'score': 0.7428370714187622}]
#
# Text: Speaker 1: देखिए सुरेशजी, हम समझते हैं आपकी परेशानी। लेकिन आप भी समझिए, यह हमारा काम है। आपको पता है कि आपके ऊपर कितना बकाया है?
# Sentiment: [{'label': 'neutral', 'score': 0.7569044828414917}]
#
# Text: Speaker 2: हाँ-हाँ, मुझे अंदाजा है। लगभग 50,000 रुपये होंगे।
# Sentiment: [{'label': 'neutral', 'score': 0.7620127201080322}]
#
# Text: Speaker 1: नहीं सुरेशजी, आप गलत हैं। आप पर कुल 75,000 रुपये बकाया है, जिसमें लेट फीस और ब्याज भी शामिल है।
# Sentiment: [{'label': 'neutral', 'score': 0.8117989301681519}]
#
# Text: Speaker 2: क्या? इतने ज्यादा? यह कैसे हो सकता है? आप लोग लूट रहे हैं क्या?
# Sentiment: [{'label': 'neutral', 'score': 0.6087375283241272}]
#
# Text: Speaker 1: देखिए सुरेशजी, गुस्सा करने से कुछ नहीं होगा। आपको समय पर पैसे जमा करने चाहिए थे। अब बताइए, कब तक आप यह राशि जमा कर सकते हैं?
# Sentiment: [{'label': 'neutral', 'score': 0.7821906208992004}]
#
# Text: Speaker 2: अरे भाई, मेरी बात तो सुनो! मेरी माँ की तबीयत खराब है, अस्पताल में भर्ती हैं। सारे पैसे उनके इलाज में खर्च हो गए।
# Sentiment: [{'label': 'neutral', 'score': 0.6431140899658203}]
#
# Text: Speaker 1:  सुरेशजी, मुझे आपकी परिस्थिति से कोई मतलब नहीं है। हमें बस अपना पैसा चाहिए। आप समझ रहे हैं या नहीं?
# Sentiment: [{'label': 'neutral', 'score': 0.762971818447113}]
#
# Text: Speaker 2: क्या बकवास कर रहे हो? तुम्हें शर्म नहीं आती? मेरी माँ मरने की कगार पर हैं और तुम पैसों की बात कर रहे हो?
# Sentiment: [{'label': 'neutral', 'score': 0.748372495174408}]
#
# Text: Speaker 1:  देखो सुरेश, मुझे तुम्हारी कहानियों से कोई फर्क नहीं पड़ता। तुमने लोन लिया है तो चुकाना पड़ेगा। समझे? वरना हम कानूनी कार्रवाई करेंगे।
# Sentiment: [{'label': 'neutral', 'score': 0.6446595788002014}]
#
# Text: Speaker 2: तुम धमकी दे रहे हो? तुम्हें पता है मैं कौन हूँ? मैं तुम्हारी नौकरी गंवा सकता हूँ।
# Sentiment: [{'label': 'neutral', 'score': 0.6167990565299988}]
#
# Text: Speaker 1:  अरे वाह! अब तुम भी धमकी दे रहे हो? चलो, देखते हैं कौन क्या कर सकता है। तुम अपनी माँ का इलाज करवाओ, मैं तुम्हारा इलाज करूँगा।
# Sentiment: [{'label': 'neutral', 'score': 0.6089824438095093}]
#
# Text: Speaker 2: बदतमीज! तुम्हारी हिम्मत कैसे हुई ऐसे बात करने की? मैं तुम्हारे बॉस से शिकायत करूँगा।
# Sentiment: [{'label': 'neutral', 'score': 0.6403448581695557}]
#
# Text: Speaker 1: करो जो करना है। लेकिन याद रखना, अगर कल तक पैसे नहीं आए तो मैं खुद तुम्हारे घर आऊंगा। और तब देखेंगे कौन किसका इलाज करता है।
# Sentiment: [{'label': 'neutral', 'score': 0.7345849275588989}]
#
# Text: Speaker 2: तुम मेरे घर आओगे? ठीक है, आ जाओ। देखता हूँ कैसे आते हो। मैं पुलिस को बुला लूंगा।
# Sentiment: [{'label': 'neutral', 'score': 0.7594264149665833}]
#
# Text: Speaker 1: अरे वाह! पुलिस? बहुत अच्छा। हम भी देखेंगे कि पुलिस किसका साथ देती है - एक कर्जदार का या एक कानूनी कंपनी का।
# Sentiment: [{'label': 'neutral', 'score': 0.5997920632362366}]
#
# Text: Speaker 2: तुम... तुम बहुत बुरे इंसान हो। मेरी मजबूरी का फायदा उठा रहे हो।
# Sentiment: [{'label': 'neutral', 'score': 0.7304486632347107}]
#
# Text: Speaker 1:  हाँ-हाँ, मैं बहुत बुरा हूँ। लेकिन तुमसे तो अच्छा ही हूँ। कम से कम मैं अपने वादे तो पूरे करता हूँ।
# Sentiment: [{'label': 'neutral', 'score': 0.5840180516242981}]
#
# Text: Speaker 2: क्या मतलब? मैंने कभी वादा तोड़ा है क्या?
# Sentiment: [{'label': 'neutral', 'score': 0.6705604791641235}]
#
# Text: Speaker 1: अरे सुरेश भाई, तुमने हर महीने EMI भरने का वादा किया था। वो क्या हुआ? भूल गए?
# Sentiment: [{'label': 'neutral', 'score': 0.7383125424385071}]
#
# Text: Speaker 2:  देखो, मैं समझता हूँ। लेकिन अभी मेरे पास सच में पैसे नहीं हैं। क्या कोई और तरीका नहीं है?
# Sentiment: [{'label': 'neutral', 'score': 0.6758719682693481}]
#
# Text: Speaker 1: तरीका तो है। लेकिन उसके लिए तुम्हें कुछ करना होगा।
# Sentiment: [{'label': 'neutral', 'score': 0.8052720427513123}]
#
# Text: Speaker 2: क्या करना होगा? बताओ, मैं तैयार हूँ।
# Sentiment: [{'label': 'neutral', 'score': 0.7367908358573914}]
#
# Text: Speaker 1: पहले तो अपनी माँ का इलाज बंद करो। उन पैसों से हमारा कर्ज चुका दो।
# Sentiment: [{'label': 'neutral', 'score': 0.7944076657295227}]
#
# Text: Speaker 2:  क्या बकवास कर रहे हो? तुम पागल हो गए हो क्या?
# Sentiment: [{'label': 'neutral', 'score': 0.6480734944343567}]
#
# Text: Speaker 1: अरे नहीं-नहीं, मैं तो मजाक कर रहा था। तुम तो बहुत जल्दी गुस्सा हो जाते हो।
# Sentiment: [{'label': 'neutral', 'score': 0.7757014036178589}]
#
# Text: Speaker 2:  तुम्हें यह सब मजाक लगता है? मेरी जिंदगी बर्बाद हो रही है और तुम मजाक कर रहे हो?
# Sentiment: [{'label': 'neutral', 'score': 0.7154635787010193}]
#
# Text: Speaker 1: अच्छा सुनो, मैं तुम्हें एक और मौका देता हूँ। कल तक 25,000 रुपये जमा कर दो। बाकी के लिए हम एक नया प्लान बना लेंगे।
# Sentiment: [{'label': 'neutral', 'score': 0.7683093547821045}]
#
# Text: Speaker 2: 25,000? इतने पैसे कहाँ से लाऊँ मैं?
# Sentiment: [{'label': 'neutral', 'score': 0.4975918233394623}]
#
# Text: Speaker 1: वो तुम्हारी समस्या है। चाहे दोस्तों से उधार लो, या फिर कुछ बेच दो। लेकिन कल तक पैसे चाहिए।
# Sentiment: [{'label': 'neutral', 'score': 0.7621716260910034}]
#
# Text: Speaker 2: तुम समझ क्यों नहीं रहे हो? मेरे पास सच में पैसे नहीं हैं।
# Sentiment: [{'label': 'neutral', 'score': 0.7717481255531311}]
#
# Text: Speaker 1: देखो सुरेश, मुझे लगता है तुम समझ नहीं रहे हो। अगर तुम कल तक पैसे नहीं देते, तो मैं तुम्हारे ऑफिस आऊंगा और सबके सामने तुम्हारी पोल खोल दूंगा।
# Sentiment: [{'label': 'neutral', 'score': 0.6691381335258484}]
#
# Text: Speaker 2:  नहीं-नहीं, ऐसा मत करना। मेरी इज्जत का सवाल है।
# Sentiment: [{'label': 'neutral', 'score': 0.775933027267456}]
#
# Text: Speaker 1: तो फिर ठीक है। कल तक पैसे जमा कर दो। वरना तुम जानते हो क्या होगा।
# Sentiment: [{'label': 'neutral', 'score': 0.7547315955162048}]
#
# Text: Speaker 2: ठीक है, मैं कोशिश करूँगा। लेकिन प्लीज, मेरे ऑफिस मत आना।
# Sentiment: [{'label': 'neutral', 'score': 0.8263183832168579}]
#
# Text: Speaker 1: बहुत अच्छा। अब तुम समझदारी की बात कर रहे हो। याद रखना, कल शाम 5 बजे तक पैसे नहीं आए तो मैं सीधा तुम्हारे ऑफिस पहुँच जाऊंगा।
# Sentiment: [{'label': 'neutral', 'score': 0.7374106049537659}]
#
# Text: Speaker 2: हाँ-हाँ, मैं समझ गया। मैं पूरी कोशिश करूँगा।
# Sentiment: [{'label': 'neutral', 'score': 0.8119152784347534}]
#
# Text: Speaker 1: ठीक है। और हाँ, अगली बार जब लोन लो तो याद रखना - समय पर पैसे नहीं चुकाओगे तो ऐसे ही परेशान होना पड़ेगा।
# Sentiment: [{'label': 'neutral', 'score': 0.7553325295448303}]
#
# Text: Speaker 2:  हाँ, मैं समझ गया। अब मैं रखता हूँ।
# Sentiment: [{'label': 'neutral', 'score': 0.7019258737564087}]
#
# Text: Speaker 1: ठीक है। और याद रखना, कल शाम 5 बजे। एक मिनट की भी देरी हुई तो...
# Sentiment: [{'label': 'neutral', 'score': 0.8406001925468445}]
#
# Text: Speaker 2: हाँ-हाँ, मैंने कहा ना मैं कोशिश करूँगा।
# Sentiment: [{'label': 'neutral', 'score': 0.7940505146980286}]
#
# Text: Speaker 1: कोशिश नहीं, करना होगा। समझे? अच्छा, अब रखता हूँ। कल मिलते हैं - या तो बैंक में, या फिर तुम्हारे ऑफिस में।
# Sentiment: [{'label': 'neutral', 'score': 0.7823837995529175}]
#
# Text: Speaker 2:  हाँ, ठीक है। नमस्ते।
# Sentiment: [{'label': 'neutral', 'score': 0.7611944675445557}]

# %% [markdown]
# ### NAMED ENTITY RECOGNITION

# %%
from transformers import pipeline

ner_model = pipeline('ner', aggregation_strategy = 'simple')
print(ner_model(full_translation))
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# c:\Users\nalin\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\nalin\.cache\huggingface\hub\models--dbmdz--bert-large-cased-finetuned-conll03-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# [{'entity_group': 'PER', 'score': 0.9928649, 'word': 'Rajesh', 'start': 34, 'end': 40}, {'entity_group': 'ORG', 'score': 0.99738705, 'word': 'CFI Finance Company', 'start': 42, 'end': 61}, {'entity_group': 'PER', 'score': 0.9872873, 'word': 'Shri Suresh Kumar', 'start': 78, 'end': 95}, {'entity_group': 'PER', 'score': 0.9863652, 'word': 'Suresh', 'start': 117, 'end': 123}, {'entity_group': 'PER', 'score': 0.9547155, 'word': 'Sureshji', 'start': 156, 'end': 164}, {'entity_group': 'PER', 'score': 0.93949485, 'word': 'Sureshji', 'start': 401, 'end': 409}, {'entity_group': 'PER', 'score': 0.9370386, 'word': 'Sureshji', 'start': 586, 'end': 594}, {'entity_group': 'PER', 'score': 0.9344972, 'word': 'Sureshji', 'start': 756, 'end': 764}, {'entity_group': 'PER', 'score': 0.9193279, 'word': 'Sureshji', 'start': 1038, 'end': 1046}, {'entity_group': 'PER', 'score': 0.95006585, 'word': 'Suresh', 'start': 1256, 'end': 1262}]
